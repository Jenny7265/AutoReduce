# %%
from autoreduce import *
import numpy as np

# %% [markdown]
# $ \dot{x} = f(x, \Theta) + g(x)u \\ y = Cx  \\
# y = h(x, \Theta)$

# %%
# Post conservation law model
n = 8
nouts = 1 # Number of outputs
# Either
# sys.load_SBML_model('my_sbml_model.xml')

# OR write ODEs
#      x = ES, P
#      P = a, d, k, Etot, Stot

# parameter values
P = np.zeros(20)
P[0] = 10  #P0
P[1] = 10  #P1
P[2] = 0.1 #P2
P[3] = 1   #P3
P[4] = 1   #P4

P[5] = 10  #P0
P[6] = 10  #P1
P[7] = 0.1 #P2
P[8] = 1   #P3
P[9] = 1   #P4

P[10] = 10  #P0
P[11] = 10  #P1
P[12] = 0.1 #P2
P[13] = 1   #P3
P[14] = 1   #P4

P[15] = 10  #P0
P[16] = 10  #P1
P[17] = 0.1 #P2
P[18] = 1   #P3
P[19] = 1   #P4

params_values = P.copy()
timepoints_ode = np.linspace(0, 150, 100) # timepoints for simulation

x_init = np.zeros(n) # Initial conditions

error_tol = 100
nstates_tol = 1
x,f,P = load_ODE_model(n, len(params_values))
params = P

f[0] = P[0]*(P[3] - x[0])*(P[4] - x[0] - x[1]) - P[1]*x[0] - P[2]*x[0]
f[1] = P[2]*x[0]

f[2] = P[5]*(P[8] - x[2])*(P[9] - x[2] - x[3]) - P[6]*x[2] - P[7]*x[2]
f[3] = P[7]*x[2]

f[4] = P[10]*(P[13] - x[4])*(P[14] - x[4] - x[5]) - P[11]*x[4] - P[12]*x[4]
f[5] = P[12]*x[4]

f[6] = P[15]*(P[18] - x[6])*(P[19] - x[6] - x[7]) - P[16]*x[6] - P[17]*x[6]
f[7] = P[17]*x[6]

C = np.zeros((nouts,len(x)), dtype=int)
C[0][1] = 1
C = C.tolist()
sys = System(x,f,params=params,C=C, params_values=params_values,x_init=[0,0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 44
#      40 x_init = np.zeros(n) # Initial conditions
#      41
#      42 error_tol = 100
#      43 nstates_tol = 1
# ---> 44 x,f,P = load_ODE_model(n, len(params_values))
#      45 params = P
#      46
#      47 f[0] = P[0]*(P[3] - x[0])*(P[4] - x[0] - x[1]) - P[1]*x[0] - P[2]*x[0]
#
# File ~\autoreduce\autoreduce\converters.py:17, in load_ODE_model(n_states, n_params)
#      15 def load_ODE_model(n_states, n_params=0):
#      16     """Directly load ODE with sympy"""
# ---> 17     return ode_to_sympy(n_states, n_params)
#
# File ~\autoreduce\autoreduce\converters.py:34, in ode_to_sympy(odesize, n_params)
#      32     vars()[str_f] = symbols("f%d" % i)
#      33     vars()[str_var] = symbols("x%d" % i)
# ---> 34     f.append(vars()[str_f])
#      35     x.append(vars()[str_var])
#      36 for k in range(n_params):
#
# KeyError: 'f0'

# %%
from autoreduce.utils import get_ODE
sys_ode = get_ODE(sys, timepoints_ode)
sol = sys_ode.solve_system().T
try:
    import matplotlib.pyplot as plt
    plt.plot(timepoints_ode, np.transpose(np.array(C)@sol))
    plt.xlabel('Time')
    plt.ylabel('[Product]')
    plt.show()
except:
    print('Plotting libraries missing.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 from autoreduce.utils import get_ODE
# ----> 2 sys_ode = get_ODE(sys, timepoints_ode)
#       3 sol = sys_ode.solve_system().T
#       4 try:
#       5     import matplotlib.pyplot as plt
#
# NameError: name 'sys' is not defined

# %%
from autoreduce.utils import get_SSM
timepoints_ssm = np.linspace(0,60,10)
sys_ssm = get_SSM(sys, timepoints_ssm)
Ss = sys_ssm.compute_SSM(normalize = True) # len(timepoints) x len(params) x len(states)
out_Ss = []
for i in range(len(params)):
    out_Ss.append((np.array(C)@(Ss[:,i,:].T)))
out_Ss = np.reshape(np.array(out_Ss), (len(timepoints_ssm), len(params), nouts))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 from autoreduce.utils import get_SSM
#       2 timepoints_ssm = np.linspace(0,60,10)
# ----> 3 sys_ssm = get_SSM(sys, timepoints_ssm)
#       4 Ss = sys_ssm.compute_SSM(normalize = True) # len(timepoints) x len(params) x len(states)
#       5 out_Ss = []
#       6 for i in range(len(params)):
#
# NameError: name 'sys' is not defined

# %%
try:
    import seaborn as sn
    for j in range(nouts):
        sn.heatmap(out_Ss[:,:,j].T)
        plt.xlabel('Time')
        plt.ylabel('Parameters')
        plt.title('Sensitivity of output[{0}] with respect to all parameters'.format(j))
        plt.show()
except:
    print('Plotting libraries missing.')

# %%
from autoreduce.utils import get_reducible
timepoints_ssm = np.linspace(0,60,10)
timepoints_ode = np.linspace(0, 100, 100)
sys_reduce = get_reducible(sys, timepoints_ode, timepoints_ssm)
results = sys_reduce.reduce_simple(, skip_numerical_computation = True)
# Out:
# Successful solution obtained with states: [x1]!
# SSM Progress: |██████████████████████████████████████████████████| 100.0% Complete
# SSM Progress: |██████████████████████████████████████████████████| 100.0% Complete
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 timepoints_ode = np.linspace(0, 100, 100)
#       4 sys_reduce = get_reducible(sys, timepoints_ode, timepoints_ssm)
# ----> 5 results = sys_reduce.reduce_simple()
#
# File ~\Box\Research\Caltech biotools and files\autoReduce\autoreduce\model_reduction.py:1037, in Reduce.reduce_simple(self, **kwargs)
#    1035         else:
#    1036             Se, R = self.get_robustness_metric(reduced_sys, **kwargs)
# -> 1037         results_dict[reduced_sys] = [e, Se, R]
#    1038 self.results_dict = results_dict
#    1039 return self.results_dict
#
# TypeError: unhashable type: 'System'

# %%
results
# Out:
# {<autoreduce.system.System at 0x28049db40a0>: [0.004223796000449995,
#   array([1602.00536597,  217.03400257,  847.81758415,  512.61413589,
#          1962.49827603]),
#   2.0355356851167846e-07]}

# %%
err = results[list(results.keys())[0]][0]
Se = results[list(results.keys())[0]][1]
weighted_se = 0
for p, Se_i in zip(params_values, Se):
    weighted_se += p*Se_i

# %%
d_R = weighted_se/err
d_R
# Out:
# 4912710.711770492

# %%
w1 = 1
w2 = 1e-3
r = w1*err + w2*d_R
r
# Out:
# 4912.714935566492

# %%
slow_system, fast_system = sys_reduce.solve_timescale_separation([x[1]])
slow_system.f[0]
# Out:
# Successful time-scale separation solution obtained with states: [x1]!
# P2*(P0*P3 + P0*P4 - P0*x1 + P1 + P2 - sqrt(P0**2*P3**2 - 2*P0**2*P3*P4 + 2*P0**2*P3*x1 + P0**2*P4**2 - 2*P0**2*P4*x1 + P0**2*x1**2 + 2*P0*P1*P3 + 2*P0*P1*P4 - 2*P0*P1*x1 + 2*P0*P2*P3 + 2*P0*P2*P4 - 2*P0*P2*x1 + P1**2 + 2*P1*P2 + P2**2))/(2*P0)
